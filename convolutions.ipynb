# %% [markdown]
# # 🎆 Convolutions

# %% [markdown]
# In this notebook, we'll walk through how convolutional filters can pick out different aspects of an image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from skimage import data
from skimage.color import rgb2gray
from skimage.transform import resize

# %% [markdown]
# ## 0. Original Input Image <a name="orig"></a>

# %%
im = rgb2gray(data.coffee())
im = resize(im, (64, 64))
print(im.shape)

plt.axis("off")
plt.imshow(im, cmap="gray")
# Out:
# (64, 64)

# %% [markdown]
# ## Horizontal Edge Filter <a name="hor"></a>

# %%
filter1 = np.array([[1, 1, 1], [0, 0, 0], [-1, -1, -1]])

new_image = np.zeros(im.shape)

im_pad = np.pad(im, 1, "constant")

for i in range(im.shape[0]):
    for j in range(im.shape[1]):
        try:
            new_image[i, j] = (
                im_pad[i - 1, j - 1] * filter1[0, 0]
                + im_pad[i - 1, j] * filter1[0, 1]
                + im_pad[i - 1, j + 1] * filter1[0, 2]
                + im_pad[i, j - 1] * filter1[1, 0]
                + im_pad[i, j] * filter1[1, 1]
                + im_pad[i, j + 1] * filter1[1, 2]
                + im_pad[i + 1, j - 1] * filter1[2, 0]
                + im_pad[i + 1, j] * filter1[2, 1]
                + im_pad[i + 1, j + 1] * filter1[2, 2]
            )
        except:
            pass

plt.axis("off")
plt.imshow(new_image, cmap="Greys")

# %% [markdown]
# ## Vertical Edge Filter <a name="ver"></a>

# %%
filter2 = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]])

new_image = np.zeros(im.shape)

im_pad = np.pad(im, 1, "constant")

for i in range(im.shape[0]):
    for j in range(im.shape[1]):
        try:
            new_image[i, j] = (
                im_pad[i - 1, j - 1] * filter2[0, 0]
                + im_pad[i - 1, j] * filter2[0, 1]
                + im_pad[i - 1, j + 1] * filter2[0, 2]
                + im_pad[i, j - 1] * filter2[1, 0]
                + im_pad[i, j] * filter2[1, 1]
                + im_pad[i, j + 1] * filter2[1, 2]
                + im_pad[i + 1, j - 1] * filter2[2, 0]
                + im_pad[i + 1, j] * filter2[2, 1]
                + im_pad[i + 1, j + 1] * filter2[2, 2]
            )
        except:
            pass

plt.axis("off")
plt.imshow(new_image, cmap="Greys")

# %% [markdown]
# ## Horizontal Edge Filter with Stride 2 <a name="hor2"></a>

# %%
filter1 = np.array([[1, 1, 1], [0, 0, 0], [-1, -1, -1]])

stride = 2

new_image = np.zeros((int(im.shape[0] / stride), int(im.shape[1] / stride)))

im_pad = np.pad(im, 1, "constant")

for i in range(0, im.shape[0], stride):
    for j in range(0, im.shape[1], stride):
        try:
            new_image[int(i / stride), int(j / stride)] = (
                im_pad[i - 1, j - 1] * filter1[0, 0]
                + im_pad[i - 1, j] * filter1[0, 1]
                + im_pad[i - 1, j + 1] * filter1[0, 2]
                + im_pad[i, j - 1] * filter1[1, 0]
                + im_pad[i, j] * filter1[1, 1]
                + im_pad[i, j + 1] * filter1[1, 2]
                + im_pad[i + 1, j - 1] * filter1[2, 0]
                + im_pad[i + 1, j] * filter1[2, 1]
                + im_pad[i + 1, j + 1] * filter1[2, 2]
            )
        except:
            pass

plt.axis("off")
plt.imshow(new_image, cmap="Greys")

# %% [markdown]
# ## Vertical Edge Filter with Stride 2 <a name="ver2"></a>

# %%
filter2 = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]])

stride = 2

new_image = np.zeros((int(im.shape[0] / stride), int(im.shape[1] / stride)))

im_pad = np.pad(im, 1, "constant")

for i in range(0, im.shape[0], stride):
    for j in range(0, im.shape[1], stride):
        try:
            new_image[int(i / stride), int(j / stride)] = (
                im_pad[i - 1, j - 1] * filter2[0, 0]
                + im_pad[i - 1, j] * filter2[0, 1]
                + im_pad[i - 1, j + 1] * filter2[0, 2]
                + im_pad[i, j - 1] * filter2[1, 0]
                + im_pad[i, j] * filter2[1, 1]
                + im_pad[i, j + 1] * filter2[1, 2]
                + im_pad[i + 1, j - 1] * filter2[2, 0]
                + im_pad[i + 1, j] * filter2[2, 1]
                + im_pad[i + 1, j + 1] * filter2[2, 2]
            )
        except:
            pass

plt.axis("off")
plt.imshow(new_image, cmap="Greys")

# %% [markdown]
# 下面我将 **把所有关键公式自然融入到你原来的 3.1（1）1. “建立多类型沉积动力学模型”段落中**，形成一个完整、学术、可直接写入博士研究计划书的版本。
# 语言经过润色，公式嵌入自然，不会显得突兀。
#
# ---
#
# # ✅ **【最终整合版段落，可直接使用】**
#
# **1. 建立多类型沉积动力学模型**
# 本研究首先构建面向断陷盆地、斜坡带、三角洲与河流相等多沉积体系的三维沉积动力学框架。模型基础由浅水动力学方程、泥沙输运方程及底床演化方程构成，用以刻画不同沉积环境下水动力场、泥沙迁移过程及地形更新机制。
# 其中，水深与流速分布由浅水方程（Shallow Water Equations, SWE）控制：
#
# [
# \frac{\partial h}{\partial t}
# +\frac{\partial (hu)}{\partial x}
# +\frac{\partial (hv)}{\partial y}=0,
# ]
#
# [
# \frac{\partial (hu)}{\partial t}
# +\frac{\partial (hu^2)}{\partial x}
# +\frac{\partial (huv)}{\partial y}
# = -gh\frac{\partial z_b}{\partial x}
#
# * \frac{\tau_{bx}}{\rho},
#   ]
#
# [
# \frac{\partial (hv)}{\partial t}
# +\frac{\partial (huv)}{\partial x}
# +\frac{\partial (hv^2)}{\partial y}
# = -gh\frac{\partial z_b}{\partial y}
#
# * \frac{\tau_{by}}{\rho},
#   ]
#
# 用于描述水流在不同地形背景下的运动特征。泥沙浓度演化采用对流–扩散输运方程：
#
# [
# \frac{\partial (hC)}{\partial t}
#
# * \frac{\partial (hCu)}{\partial x}
# * \frac{\partial (hCv)}{\partial y}
#   = \frac{\partial }{\partial x}
#   \left(hD_s\frac{\partial C}{\partial x}\right)
#   +\frac{\partial }{\partial y}
#   \left(hD_s\frac{\partial C}{\partial y}\right)
# * E - D,
#   ]
#
# 其中 (C) 为泥沙浓度，(E) 与 (D) 分别表示起动与沉降项。泥沙输移能力采用经典 Engelund–Hansen 或 MPM 输沙率公式，例如：
#
# [
# q_s = 8(\tau_* - \tau_{*c})^{1.5}
# \sqrt{(s-1)g d_{50}^3},
# ]
#
# 以量化不同水动力条件下的输沙强度。底床高程随时间的沉积–侵蚀演化由 Exner 方程描述：
#
# [
# (1-\lambda_p)\frac{\partial z_b}{\partial t}
#
# * \frac{\partial q_s}{\partial x}
# * \frac{\partial q_s}{\partial y}=0,
#   ]
#
# 实现沉积单元（砂坝、河道充填、分流河道等）的自发形成与演化。对于河流相与三角洲相中典型的弯曲河道，其横向迁移过程引入 Ikeda 模型：
#
# [
# \frac{\partial M}{\partial t}
# = E_0\left(\frac{u_s}{u_c}-1\right),
# ]
#
# 用于生成点坝、旁侧堤与河道摆动结构。
# 通过上述物理方程族的耦合求解，本研究将实现不同沉积动力条件下三维储层结构的可控生成，为后续生成式模型训练提供物理一致、结构多样的高保真基础样本。
#
# ---
#
# 如果你愿意，我可以继续为你完成：
#
# ✅ **把 3.1（1）2. “融入构造变形机制”写成同样风格的段落**（含构造力学 PDE）
# ✅ **把整个 3.1 改成连续、统一风格的正式 proposal 版本**
# ✅ **转换成英文科研计划书语言**
#
# 需要我继续吗？

# %% [markdown]
# 下面我将 **重新用标准 LaTeX 形式写出 Exner 方程**，并 **补充说明该方程中每一项的含义、物理意义，以及方程的来源与作用**。
# 你可以直接复制到论文或博士研究计划中使用。
#
# ---
#
# # ✅ **Exner 方程（LateX 规范版）**
#
# [
# (1-\lambda_p),\frac{\partial z_b}{\partial t}
#
# * \frac{\partial q_{sx}}{\partial x}
# * \frac{\partial q_{sy}}{\partial y}
#   = 0
#   ]
#
# 为了更清晰，也可写成更常见的紧凑形式：
#
# [
# (1-\lambda_p)\frac{\partial z_b}{\partial t}
#
# * \nabla \cdot \mathbf{q_s}
#   = 0,
#   \qquad
#   \mathbf{q_s} = (q_{sx},, q_{sy})
#   ]
#
# ---
#
# # ✅ **Exner 方程中的各符号含义**
#
# * (z_b(x,y,t))：**底床高程（bed elevation）**
# * (\lambda_p)：**沉积物孔隙度（porosity）**
# * (q_{sx},, q_{sy})：**泥沙输移率（sediment flux）在 x、y 方向的分量**
# * (\mathbf{q_s})：**单位宽度输沙率向量（sediment transport vector）**
# * (\nabla \cdot \mathbf{q_s})：**输沙率散度，表示泥沙的净流入或流出**
#
# ---
#
# # ✅ **物理含义说明（写进计划书/论文必备）**
#
# Exner 方程描述了 **沉积–侵蚀过程与地形变化之间的守恒关系**：
#
# * 当 ( \nabla\cdot \mathbf{q_s} > 0 ) 时（泥沙更多地流出某区域） → **侵蚀**（(\partial z_b/\partial t < 0)）
# * 当 ( \nabla\cdot \mathbf{q_s} < 0 ) 时（泥沙更多地流入某区域） → **沉积**（(\partial z_b/\partial t > 0)）
#
# 孔隙度因子 ( (1-\lambda_p) ) 表示：沉积物堆积并不会完全增加等体积的固体，而是带有孔隙，因此沉积体积变化需要考虑固体体积分数。
#
# ---
#
# # ✅ **“上述公式用到的其他公式”说明（满足你要求的补充解释）**
#
# Exner 方程本身并不能独立求解，它必须与 **流体动力学 + 泥沙输运 + 输沙率公式**耦合使用。
#
# 在你的体系中，Exner 方程依赖以下公式：
#
# ---
#
# ## **1. 来自浅水动力学（Shallow Water Equations）**
#
# 底床高程 (z_b) 对流速会产生反馈，因此 Exner 方程与 SWE 相互耦合：
#
# [
# \frac{\partial h}{\partial t}
# +\frac{\partial (hu)}{\partial x}
# +\frac{\partial (hv)}{\partial y}=0,
# ]
#
# [
# \frac{\partial (hu)}{\partial t}
# +\dots = -gh\frac{\partial z_b}{\partial x} + \dots
# ]
#
# **意义：**
# 底床变化影响水深 (h=z_s - z_b) ，从而影响流速 (u,v) 与水动力条件。
#
# ---
#
# ## **2. 来自泥沙浓度输运方程（Advection–Diffusion）**
#
# 泥沙浓度由该 PDE 控制：
#
# [
# \frac{\partial (hC)}{\partial t}
#
# * \frac{\partial (hCu)}{\partial x}
# * \frac{\partial (hCv)}{\partial y}
#   = \nabla\cdot (hD_s \nabla C) + E - D.
#   ]
#
# **意义：**
# 泥沙浓度 (C) 影响沉降量 (D)，进而影响到沉积/侵蚀速率（即 Exner 方程右侧来源项）
# → **没有泥沙输运方程，Exner 就无法得到沉积速率。**
#
# ---
#
# ## **3. 来自输沙率经验公式（qs 的来源）**
#
# Exner 方程中的 (\mathbf{q_s}) 完全由输沙率公式决定，如：
#
# ### **Meyer-Peter–Müller 公式（MPM）**
#
# [
# q_s = 8(\tau_* - \tau_{*c})^{1.5}
# \sqrt{(s-1)gd_{50}^3}
# ]
#
# ### 或 Engelund–Hansen 公式
#
# [
# q_s = 0.05\frac{u^5}{g,R,d_{50}}
# ]
#
# **意义：**
# 输沙能力 (q_s) 是 Exner 方程的核心输入
# → **没有输沙率公式，Exner 方程无法闭合。**
#
# ---
#
# # ✅ **最终总结（可直接写入你的 3.1 子章节作为说明句）**
#
# > 上述 Exner 方程通过泥沙输移率 (\mathbf{q_s}) 与下垫面高程 (z_b) 建立沉积—侵蚀过程与地形演化之间的守恒关系。该方程必须结合浅水动力学方程组用于计算流速场，结合对流–扩散泥沙输运方程用于计算泥沙浓度，结合经验输沙率公式（如 MPM 或 Engelund–Hansen）用于确定 (\mathbf{q_s}) 的取值，从而形成完整的沉积动力学 PDE 耦合体系。
#
# ---
#
# 如果你愿意，我可以把：
#
# ✔ **整个 3.1（1）段落改成完整 LaTeX 版**
# ✔ **把所有公式和说明集成成一个正式论文风格 Section**
# ✔ **直接帮你生成“物理机制图 + 公式框架图”**
#
# 需要继续吗？
